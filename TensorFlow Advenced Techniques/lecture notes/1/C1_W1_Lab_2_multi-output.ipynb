# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 241.9422 - y1_output_loss: 118.4787 - y2_output_loss: 121.6467 - y1_output_root_mean_squared_error: 10.9287 - y2_output_root_mean_squared_error: 11.0682 - val_loss: 39.8474 - val_y1_output_loss: 11.1547 - val_y2_output_loss: 27.4687 - val_y1_output_root_mean_squared_error: 3.3941 - val_y2_output_root_mean_squared_error: 5.3223
# Epoch 2/500
# 614/614 [==============================] - 0s 167us/sample - loss: 33.3141 - y1_output_loss: 12.5965 - y2_output_loss: 20.4383 - y1_output_root_mean_squared_error: 3.5661 - y2_output_root_mean_squared_error: 4.5384 - val_loss: 19.5274 - val_y1_output_loss: 8.0773 - val_y2_output_loss: 11.0007 - val_y1_output_root_mean_squared_error: 2.8826 - val_y2_output_root_mean_squared_error: 3.3493
# Epoch 3/500
# 614/614 [==============================] - 0s 180us/sample - loss: 29.9067 - y1_output_loss: 10.8604 - y2_output_loss: 18.7661 - y1_output_root_mean_squared_error: 3.3115 - y2_output_root_mean_squared_error: 4.3521 - val_loss: 19.0447 - val_y1_output_loss: 7.4900 - val_y2_output_loss: 11.1512 - val_y1_output_root_mean_squared_error: 2.7735 - val_y2_output_root_mean_squared_error: 3.3694
# Epoch 4/500
# 614/614 [==============================] - 0s 158us/sample - loss: 26.4004 - y1_output_loss: 10.3220 - y2_output_loss: 15.9942 - y1_output_root_mean_squared_error: 3.2121 - y2_output_root_mean_squared_error: 4.0104 - val_loss: 22.5767 - val_y1_output_loss: 8.6655 - val_y2_output_loss: 13.3080 - val_y1_output_root_mean_squared_error: 2.9888 - val_y2_output_root_mean_squared_error: 3.6938
# Epoch 5/500
# 614/614 [==============================] - 0s 173us/sample - loss: 22.1396 - y1_output_loss: 9.3203 - y2_output_loss: 12.7542 - y1_output_root_mean_squared_error: 3.0530 - y2_output_root_mean_squared_error: 3.5803 - val_loss: 19.3380 - val_y1_output_loss: 7.8271 - val_y2_output_loss: 10.9909 - val_y1_output_root_mean_squared_error: 2.8399 - val_y2_output_root_mean_squared_error: 3.3575
# Epoch 6/500
# 614/614 [==============================] - 0s 167us/sample - loss: 25.3472 - y1_output_loss: 9.5256 - y2_output_loss: 15.8858 - y1_output_root_mean_squared_error: 3.0661 - y2_output_root_mean_squared_error: 3.9932 - val_loss: 26.6104 - val_y1_output_loss: 10.8405 - val_y2_output_loss: 15.0235 - val_y1_output_root_mean_squared_error: 3.3435 - val_y2_output_root_mean_squared_error: 3.9283
# Epoch 7/500
# 614/614 [==============================] - 0s 163us/sample - loss: 28.4502 - y1_output_loss: 9.9978 - y2_output_loss: 18.2868 - y1_output_root_mean_squared_error: 3.1650 - y2_output_root_mean_squared_error: 4.2934 - val_loss: 19.8615 - val_y1_output_loss: 9.2602 - val_y2_output_loss: 10.0918 - val_y1_output_root_mean_squared_error: 3.0909 - val_y2_output_root_mean_squared_error: 3.2106
# Epoch 8/500
# 614/614 [==============================] - 0s 175us/sample - loss: 23.3371 - y1_output_loss: 8.7835 - y2_output_loss: 14.6614 - y1_output_root_mean_squared_error: 2.9531 - y2_output_root_mean_squared_error: 3.8232 - val_loss: 29.8612 - val_y1_output_loss: 9.1696 - val_y2_output_loss: 19.9287 - val_y1_output_root_mean_squared_error: 3.0708 - val_y2_output_root_mean_squared_error: 4.5201
# Epoch 9/500
# 614/614 [==============================] - 0s 176us/sample - loss: 20.5730 - y1_output_loss: 8.2228 - y2_output_loss: 12.2767 - y1_output_root_mean_squared_error: 2.8624 - y2_output_root_mean_squared_error: 3.5185 - val_loss: 18.6018 - val_y1_output_loss: 6.9976 - val_y2_output_loss: 11.1947 - val_y1_output_root_mean_squared_error: 2.6748 - val_y2_output_root_mean_squared_error: 3.3834
# Epoch 10/500
# 614/614 [==============================] - 0s 172us/sample - loss: 22.3517 - y1_output_loss: 8.1837 - y2_output_loss: 14.0820 - y1_output_root_mean_squared_error: 2.8609 - y2_output_root_mean_squared_error: 3.7639 - val_loss: 16.7908 - val_y1_output_loss: 6.3716 - val_y2_output_loss: 10.0124 - val_y1_output_root_mean_squared_error: 2.5596 - val_y2_output_root_mean_squared_error: 3.1999
# Epoch 11/500
# 614/614 [==============================] - 0s 175us/sample - loss: 18.8508 - y1_output_loss: 7.5839 - y2_output_loss: 11.1413 - y1_output_root_mean_squared_error: 2.7641 - y2_output_root_mean_squared_error: 3.3482 - val_loss: 16.3336 - val_y1_output_loss: 6.3256 - val_y2_output_loss: 9.7176 - val_y1_output_root_mean_squared_error: 2.5458 - val_y2_output_root_mean_squared_error: 3.1388
# Epoch 12/500
# 614/614 [==============================] - 0s 179us/sample - loss: 23.4065 - y1_output_loss: 8.6132 - y2_output_loss: 14.9161 - y1_output_root_mean_squared_error: 2.9294 - y2_output_root_mean_squared_error: 3.8504 - val_loss: 64.4636 - val_y1_output_loss: 10.9556 - val_y2_output_loss: 51.4090 - val_y1_output_root_mean_squared_error: 3.3666 - val_y2_output_root_mean_squared_error: 7.2890
# Epoch 13/500
# 614/614 [==============================] - 0s 184us/sample - loss: 19.5400 - y1_output_loss: 7.4167 - y2_output_loss: 12.0419 - y1_output_root_mean_squared_error: 2.7326 - y2_output_root_mean_squared_error: 3.4746 - val_loss: 15.3791 - val_y1_output_loss: 5.8222 - val_y2_output_loss: 9.1191 - val_y1_output_root_mean_squared_error: 2.4492 - val_y2_output_root_mean_squared_error: 3.0628
# Epoch 14/500
# 614/614 [==============================] - 0s 192us/sample - loss: 21.0246 - y1_output_loss: 7.7705 - y2_output_loss: 13.1403 - y1_output_root_mean_squared_error: 2.7953 - y2_output_root_mean_squared_error: 3.6347 - val_loss: 17.7167 - val_y1_output_loss: 6.9875 - val_y2_output_loss: 10.2425 - val_y1_output_root_mean_squared_error: 2.6817 - val_y2_output_root_mean_squared_error: 3.2442
# Epoch 15/500
# 614/614 [==============================] - 0s 201us/sample - loss: 19.4532 - y1_output_loss: 7.2097 - y2_output_loss: 12.2708 - y1_output_root_mean_squared_error: 2.6782 - y2_output_root_mean_squared_error: 3.5044 - val_loss: 15.8223 - val_y1_output_loss: 6.5022 - val_y2_output_loss: 8.8714 - val_y1_output_root_mean_squared_error: 2.5892 - val_y2_output_root_mean_squared_error: 3.0196
# Epoch 16/500
# 614/614 [==============================] - 0s 180us/sample - loss: 18.5227 - y1_output_loss: 7.0329 - y2_output_loss: 11.5940 - y1_output_root_mean_squared_error: 2.6373 - y2_output_root_mean_squared_error: 3.4011 - val_loss: 20.4987 - val_y1_output_loss: 6.1307 - val_y2_output_loss: 13.9722 - val_y1_output_root_mean_squared_error: 2.5072 - val_y2_output_root_mean_squared_error: 3.7700
# Epoch 17/500
# 614/614 [==============================] - 0s 207us/sample - loss: 17.7631 - y1_output_loss: 6.9761 - y2_output_loss: 10.9530 - y1_output_root_mean_squared_error: 2.6343 - y2_output_root_mean_squared_error: 3.2899 - val_loss: 17.7861 - val_y1_output_loss: 5.5754 - val_y2_output_loss: 11.7163 - val_y1_output_root_mean_squared_error: 2.3976 - val_y2_output_root_mean_squared_error: 3.4695
# Epoch 18/500
# 614/614 [==============================] - 0s 222us/sample - loss: 17.0488 - y1_output_loss: 6.4673 - y2_output_loss: 10.6111 - y1_output_root_mean_squared_error: 2.5424 - y2_output_root_mean_squared_error: 3.2535 - val_loss: 13.7649 - val_y1_output_loss: 5.3953 - val_y2_output_loss: 7.9641 - val_y1_output_root_mean_squared_error: 2.3604 - val_y2_output_root_mean_squared_error: 2.8624
# Epoch 19/500
# 614/614 [==============================] - 0s 171us/sample - loss: 16.2078 - y1_output_loss: 6.2518 - y2_output_loss: 10.0584 - y1_output_root_mean_squared_error: 2.5036 - y2_output_root_mean_squared_error: 3.1527 - val_loss: 15.8446 - val_y1_output_loss: 5.3671 - val_y2_output_loss: 10.0673 - val_y1_output_root_mean_squared_error: 2.3475 - val_y2_output_root_mean_squared_error: 3.2147
# Epoch 20/500
# 614/614 [==============================] - 0s 175us/sample - loss: 16.1415 - y1_output_loss: 5.9162 - y2_output_loss: 10.2503 - y1_output_root_mean_squared_error: 2.4390 - y2_output_root_mean_squared_error: 3.1926 - val_loss: 26.8750 - val_y1_output_loss: 7.1296 - val_y2_output_loss: 18.8852 - val_y1_output_root_mean_squared_error: 2.7108 - val_y2_output_root_mean_squared_error: 4.4189
# Epoch 21/500
# 614/614 [==============================] - 0s 160us/sample - loss: 16.2983 - y1_output_loss: 5.9254 - y2_output_loss: 10.3393 - y1_output_root_mean_squared_error: 2.4392 - y2_output_root_mean_squared_error: 3.2169 - val_loss: 26.8554 - val_y1_output_loss: 7.0638 - val_y2_output_loss: 18.9448 - val_y1_output_root_mean_squared_error: 2.6977 - val_y2_output_root_mean_squared_error: 4.4247
# Epoch 22/500
# 614/614 [==============================] - 0s 166us/sample - loss: 14.0141 - y1_output_loss: 5.2222 - y2_output_loss: 8.8772 - y1_output_root_mean_squared_error: 2.2936 - y2_output_root_mean_squared_error: 2.9587 - val_loss: 56.1571 - val_y1_output_loss: 12.3749 - val_y2_output_loss: 41.8863 - val_y1_output_root_mean_squared_error: 3.5777 - val_y2_output_root_mean_squared_error: 6.5846
# Epoch 23/500
# 614/614 [==============================] - 0s 162us/sample - loss: 17.7572 - y1_output_loss: 6.0148 - y2_output_loss: 11.7949 - y1_output_root_mean_squared_error: 2.4389 - y2_output_root_mean_squared_error: 3.4364 - val_loss: 11.7629 - val_y1_output_loss: 4.5659 - val_y2_output_loss: 6.7917 - val_y1_output_root_mean_squared_error: 2.1753 - val_y2_output_root_mean_squared_error: 2.6516
# Epoch 24/500
# 614/614 [==============================] - 0s 174us/sample - loss: 15.7376 - y1_output_loss: 5.4713 - y2_output_loss: 10.2410 - y1_output_root_mean_squared_error: 2.3438 - y2_output_root_mean_squared_error: 3.2007 - val_loss: 28.1795 - val_y1_output_loss: 8.5464 - val_y2_output_loss: 18.6861 - val_y1_output_root_mean_squared_error: 2.9752 - val_y2_output_root_mean_squared_error: 4.3963
# Epoch 25/500
# 614/614 [==============================] - 0s 163us/sample - loss: 15.6582 - y1_output_loss: 5.6210 - y2_output_loss: 10.0880 - y1_output_root_mean_squared_error: 2.3621 - y2_output_root_mean_squared_error: 3.1747 - val_loss: 10.4720 - val_y1_output_loss: 4.1919 - val_y2_output_loss: 5.9471 - val_y1_output_root_mean_squared_error: 2.0835 - val_y2_output_root_mean_squared_error: 2.4761
# Epoch 26/500
# 614/614 [==============================] - 0s 156us/sample - loss: 13.7083 - y1_output_loss: 5.3303 - y2_output_loss: 8.2785 - y1_output_root_mean_squared_error: 2.3158 - y2_output_root_mean_squared_error: 2.8888 - val_loss: 10.5132 - val_y1_output_loss: 4.1960 - val_y2_output_loss: 6.0121 - val_y1_output_root_mean_squared_error: 2.0816 - val_y2_output_root_mean_squared_error: 2.4860
# Epoch 27/500
# 614/614 [==============================] - 0s 151us/sample - loss: 12.5578 - y1_output_loss: 4.6525 - y2_output_loss: 7.9365 - y1_output_root_mean_squared_error: 2.1456 - y2_output_root_mean_squared_error: 2.8203 - val_loss: 10.1543 - val_y1_output_loss: 3.7839 - val_y2_output_loss: 6.0584 - val_y1_output_root_mean_squared_error: 1.9764 - val_y2_output_root_mean_squared_error: 2.4996
# Epoch 28/500
# 614/614 [==============================] - 0s 152us/sample - loss: 12.0861 - y1_output_loss: 4.4415 - y2_output_loss: 7.5860 - y1_output_root_mean_squared_error: 2.1105 - y2_output_root_mean_squared_error: 2.7626 - val_loss: 11.0197 - val_y1_output_loss: 4.3899 - val_y2_output_loss: 6.2937 - val_y1_output_root_mean_squared_error: 2.1311 - val_y2_output_root_mean_squared_error: 2.5452
# Epoch 29/500
# 614/614 [==============================] - 0s 170us/sample - loss: 11.9909 - y1_output_loss: 4.3879 - y2_output_loss: 7.6612 - y1_output_root_mean_squared_error: 2.0885 - y2_output_root_mean_squared_error: 2.7621 - val_loss: 23.3817 - val_y1_output_loss: 7.1643 - val_y2_output_loss: 15.4923 - val_y1_output_root_mean_squared_error: 2.7258 - val_y2_output_root_mean_squared_error: 3.9940
# Epoch 30/500
# 614/614 [==============================] - 0s 150us/sample - loss: 12.4118 - y1_output_loss: 4.3017 - y2_output_loss: 8.1411 - y1_output_root_mean_squared_error: 2.0759 - y2_output_root_mean_squared_error: 2.8465 - val_loss: 13.4203 - val_y1_output_loss: 4.1340 - val_y2_output_loss: 8.8438 - val_y1_output_root_mean_squared_error: 2.0686 - val_y2_output_root_mean_squared_error: 3.0234
# Epoch 31/500
# 614/614 [==============================] - 0s 159us/sample - loss: 12.4663 - y1_output_loss: 4.4988 - y2_output_loss: 7.9348 - y1_output_root_mean_squared_error: 2.1177 - y2_output_root_mean_squared_error: 2.8252 - val_loss: 13.5946 - val_y1_output_loss: 5.0197 - val_y2_output_loss: 8.1497 - val_y1_output_root_mean_squared_error: 2.2810 - val_y2_output_root_mean_squared_error: 2.8968
# Epoch 32/500
# 614/614 [==============================] - 0s 153us/sample - loss: 11.6718 - y1_output_loss: 4.1352 - y2_output_loss: 7.5706 - y1_output_root_mean_squared_error: 2.0302 - y2_output_root_mean_squared_error: 2.7477 - val_loss: 14.7511 - val_y1_output_loss: 4.5199 - val_y2_output_loss: 9.7161 - val_y1_output_root_mean_squared_error: 2.1663 - val_y2_output_root_mean_squared_error: 3.1715
# Epoch 33/500
# 614/614 [==============================] - 0s 156us/sample - loss: 9.2654 - y1_output_loss: 3.7165 - y2_output_loss: 5.5911 - y1_output_root_mean_squared_error: 1.9056 - y2_output_root_mean_squared_error: 2.3736 - val_loss: 8.2209 - val_y1_output_loss: 3.0176 - val_y2_output_loss: 4.9322 - val_y1_output_root_mean_squared_error: 1.7696 - val_y2_output_root_mean_squared_error: 2.2560
# Epoch 34/500
# 614/614 [==============================] - 0s 179us/sample - loss: 9.0062 - y1_output_loss: 3.2497 - y2_output_loss: 5.8618 - y1_output_root_mean_squared_error: 1.7952 - y2_output_root_mean_squared_error: 2.4049 - val_loss: 14.9032 - val_y1_output_loss: 3.9062 - val_y2_output_loss: 10.4876 - val_y1_output_root_mean_squared_error: 2.0121 - val_y2_output_root_mean_squared_error: 3.2947
# Epoch 35/500
# 614/614 [==============================] - 0s 176us/sample - loss: 8.8891 - y1_output_loss: 3.1617 - y2_output_loss: 5.6511 - y1_output_root_mean_squared_error: 1.7849 - y2_output_root_mean_squared_error: 2.3881 - val_loss: 8.3465 - val_y1_output_loss: 3.3572 - val_y2_output_loss: 4.6984 - val_y1_output_root_mean_squared_error: 1.8668 - val_y2_output_root_mean_squared_error: 2.2049
# Epoch 36/500
# 614/614 [==============================] - 0s 182us/sample - loss: 9.7581 - y1_output_loss: 3.2363 - y2_output_loss: 6.4680 - y1_output_root_mean_squared_error: 1.8045 - y2_output_root_mean_squared_error: 2.5499 - val_loss: 9.9350 - val_y1_output_loss: 3.0359 - val_y2_output_loss: 6.5735 - val_y1_output_root_mean_squared_error: 1.7742 - val_y2_output_root_mean_squared_error: 2.6052
# Epoch 37/500
# 614/614 [==============================] - 0s 158us/sample - loss: 9.4907 - y1_output_loss: 2.9111 - y2_output_loss: 6.5055 - y1_output_root_mean_squared_error: 1.7143 - y2_output_root_mean_squared_error: 2.5597 - val_loss: 12.8876 - val_y1_output_loss: 3.9857 - val_y2_output_loss: 8.4944 - val_y1_output_root_mean_squared_error: 2.0333 - val_y2_output_root_mean_squared_error: 2.9586
# Epoch 38/500
# 614/614 [==============================] - 0s 163us/sample - loss: 9.3467 - y1_output_loss: 3.0207 - y2_output_loss: 6.2672 - y1_output_root_mean_squared_error: 1.7397 - y2_output_root_mean_squared_error: 2.5140 - val_loss: 8.5332 - val_y1_output_loss: 3.1663 - val_y2_output_loss: 5.0719 - val_y1_output_root_mean_squared_error: 1.8127 - val_y2_output_root_mean_squared_error: 2.2907
# Epoch 39/500
# 614/614 [==============================] - 0s 173us/sample - loss: 8.7632 - y1_output_loss: 2.7992 - y2_output_loss: 6.0357 - y1_output_root_mean_squared_error: 1.6658 - y2_output_root_mean_squared_error: 2.4471 - val_loss: 12.0388 - val_y1_output_loss: 2.5911 - val_y2_output_loss: 9.0505 - val_y1_output_root_mean_squared_error: 1.6390 - val_y2_output_root_mean_squared_error: 3.0582
# Epoch 40/500
# 614/614 [==============================] - 0s 195us/sample - loss: 6.9747 - y1_output_loss: 2.4554 - y2_output_loss: 4.5037 - y1_output_root_mean_squared_error: 1.5694 - y2_output_root_mean_squared_error: 2.1241 - val_loss: 8.2082 - val_y1_output_loss: 2.2801 - val_y2_output_loss: 5.6540 - val_y1_output_root_mean_squared_error: 1.5374 - val_y2_output_root_mean_squared_error: 2.4176
# Epoch 41/500
# 614/614 [==============================] - 0s 172us/sample - loss: 9.1373 - y1_output_loss: 2.8087 - y2_output_loss: 6.3472 - y1_output_root_mean_squared_error: 1.6706 - y2_output_root_mean_squared_error: 2.5192 - val_loss: 9.6463 - val_y1_output_loss: 4.1087 - val_y2_output_loss: 5.2146 - val_y1_output_root_mean_squared_error: 2.0646 - val_y2_output_root_mean_squared_error: 2.3203
# Epoch 42/500
# 614/614 [==============================] - 0s 164us/sample - loss: 8.6047 - y1_output_loss: 2.6354 - y2_output_loss: 5.8911 - y1_output_root_mean_squared_error: 1.6302 - y2_output_root_mean_squared_error: 2.4386 - val_loss: 6.1820 - val_y1_output_loss: 2.1533 - val_y2_output_loss: 3.8315 - val_y1_output_root_mean_squared_error: 1.4943 - val_y2_output_root_mean_squared_error: 1.9872
# Epoch 43/500
# 614/614 [==============================] - 0s 181us/sample - loss: 7.9480 - y1_output_loss: 2.3564 - y2_output_loss: 5.5591 - y1_output_root_mean_squared_error: 1.5294 - y2_output_root_mean_squared_error: 2.3683 - val_loss: 6.3319 - val_y1_output_loss: 2.2707 - val_y2_output_loss: 3.8426 - val_y1_output_root_mean_squared_error: 1.5355 - val_y2_output_root_mean_squared_error: 1.9935
# Epoch 44/500
# 614/614 [==============================] - 0s 180us/sample - loss: 9.3156 - y1_output_loss: 2.7259 - y2_output_loss: 6.6671 - y1_output_root_mean_squared_error: 1.6512 - y2_output_root_mean_squared_error: 2.5669 - val_loss: 17.5582 - val_y1_output_loss: 4.9809 - val_y2_output_loss: 11.9673 - val_y1_output_root_mean_squared_error: 2.2726 - val_y2_output_root_mean_squared_error: 3.5204
# Epoch 45/500
# 614/614 [==============================] - 0s 201us/sample - loss: 8.2464 - y1_output_loss: 2.7292 - y2_output_loss: 5.4505 - y1_output_root_mean_squared_error: 1.6585 - y2_output_root_mean_squared_error: 2.3443 - val_loss: 6.8253 - val_y1_output_loss: 2.8250 - val_y2_output_loss: 3.7765 - val_y1_output_root_mean_squared_error: 1.7091 - val_y2_output_root_mean_squared_error: 1.9759
# Epoch 46/500
# 614/614 [==============================] - 0s 178us/sample - loss: 7.6279 - y1_output_loss: 2.3932 - y2_output_loss: 5.2471 - y1_output_root_mean_squared_error: 1.5492 - y2_output_root_mean_squared_error: 2.2864 - val_loss: 7.1760 - val_y1_output_loss: 2.1632 - val_y2_output_loss: 4.7708 - val_y1_output_root_mean_squared_error: 1.4982 - val_y2_output_root_mean_squared_error: 2.2207
# Epoch 47/500
# 614/614 [==============================] - 0s 169us/sample - loss: 7.3952 - y1_output_loss: 2.1900 - y2_output_loss: 5.2480 - y1_output_root_mean_squared_error: 1.4840 - y2_output_root_mean_squared_error: 2.2788 - val_loss: 8.2561 - val_y1_output_loss: 2.5992 - val_y2_output_loss: 5.3645 - val_y1_output_root_mean_squared_error: 1.6390 - val_y2_output_root_mean_squared_error: 2.3601
# Epoch 48/500
# 614/614 [==============================] - 0s 159us/sample - loss: 6.9808 - y1_output_loss: 2.1870 - y2_output_loss: 4.8239 - y1_output_root_mean_squared_error: 1.4696 - y2_output_root_mean_squared_error: 2.1957 - val_loss: 10.8056 - val_y1_output_loss: 3.7368 - val_y2_output_loss: 6.7243 - val_y1_output_root_mean_squared_error: 1.9646 - val_y2_output_root_mean_squared_error: 2.6355
# Epoch 49/500
# 614/614 [==============================] - 0s 153us/sample - loss: 6.5001 - y1_output_loss: 2.0013 - y2_output_loss: 4.5235 - y1_output_root_mean_squared_error: 1.4129 - y2_output_root_mean_squared_error: 2.1222 - val_loss: 8.1376 - val_y1_output_loss: 2.1810 - val_y2_output_loss: 5.6731 - val_y1_output_root_mean_squared_error: 1.5028 - val_y2_output_root_mean_squared_error: 2.4247
# Epoch 50/500
# 614/614 [==============================] - 0s 186us/sample - loss: 6.2005 - y1_output_loss: 1.8147 - y2_output_loss: 4.3295 - y1_output_root_mean_squared_error: 1.3526 - y2_output_root_mean_squared_error: 2.0907 - val_loss: 6.3026 - val_y1_output_loss: 1.7959 - val_y2_output_loss: 4.2943 - val_y1_output_root_mean_squared_error: 1.3649 - val_y2_output_root_mean_squared_error: 2.1070
# Epoch 51/500
# 614/614 [==============================] - 0s 179us/sample - loss: 7.4897 - y1_output_loss: 2.1632 - y2_output_loss: 5.3315 - y1_output_root_mean_squared_error: 1.4705 - y2_output_root_mean_squared_error: 2.3081 - val_loss: 6.4390 - val_y1_output_loss: 1.7911 - val_y2_output_loss: 4.4311 - val_y1_output_root_mean_squared_error: 1.3624 - val_y2_output_root_mean_squared_error: 2.1407
# Epoch 52/500
# 614/614 [==============================] - 0s 172us/sample - loss: 5.8322 - y1_output_loss: 1.7654 - y2_output_loss: 4.0559 - y1_output_root_mean_squared_error: 1.3330 - y2_output_root_mean_squared_error: 2.0138 - val_loss: 5.5355 - val_y1_output_loss: 1.7259 - val_y2_output_loss: 3.6378 - val_y1_output_root_mean_squared_error: 1.3385 - val_y2_output_root_mean_squared_error: 1.9350
# Epoch 53/500
# 614/614 [==============================] - 0s 160us/sample - loss: 12.7689 - y1_output_loss: 3.9889 - y2_output_loss: 8.7026 - y1_output_root_mean_squared_error: 2.0023 - y2_output_root_mean_squared_error: 2.9597 - val_loss: 9.9135 - val_y1_output_loss: 4.0711 - val_y2_output_loss: 5.6340 - val_y1_output_root_mean_squared_error: 2.0445 - val_y2_output_root_mean_squared_error: 2.3945
# Epoch 54/500
# 614/614 [==============================] - 0s 156us/sample - loss: 8.9564 - y1_output_loss: 2.8091 - y2_output_loss: 6.0642 - y1_output_root_mean_squared_error: 1.6841 - y2_output_root_mean_squared_error: 2.4739 - val_loss: 7.1283 - val_y1_output_loss: 2.1571 - val_y2_output_loss: 4.7167 - val_y1_output_root_mean_squared_error: 1.4966 - val_y2_output_root_mean_squared_error: 2.2110
# Epoch 55/500
# 614/614 [==============================] - 0s 149us/sample - loss: 7.0216 - y1_output_loss: 2.1748 - y2_output_loss: 4.9699 - y1_output_root_mean_squared_error: 1.4623 - y2_output_root_mean_squared_error: 2.2098 - val_loss: 27.1317 - val_y1_output_loss: 5.8166 - val_y2_output_loss: 20.4196 - val_y1_output_root_mean_squared_error: 2.4577 - val_y2_output_root_mean_squared_error: 4.5926
# Epoch 56/500
# 614/614 [==============================] - 0s 167us/sample - loss: 6.8093 - y1_output_loss: 2.0441 - y2_output_loss: 4.7054 - y1_output_root_mean_squared_error: 1.4351 - y2_output_root_mean_squared_error: 2.1794 - val_loss: 6.3522 - val_y1_output_loss: 1.7327 - val_y2_output_loss: 4.4225 - val_y1_output_root_mean_squared_error: 1.3352 - val_y2_output_root_mean_squared_error: 2.1376
# Epoch 57/500
# 614/614 [==============================] - 0s 153us/sample - loss: 5.2347 - y1_output_loss: 1.5154 - y2_output_loss: 3.8035 - y1_output_root_mean_squared_error: 1.2322 - y2_output_root_mean_squared_error: 1.9278 - val_loss: 8.1970 - val_y1_output_loss: 2.3920 - val_y2_output_loss: 5.5468 - val_y1_output_root_mean_squared_error: 1.5716 - val_y2_output_root_mean_squared_error: 2.3931
# Epoch 58/500
# 614/614 [==============================] - 0s 151us/sample - loss: 7.5835 - y1_output_loss: 2.1106 - y2_output_loss: 5.4148 - y1_output_root_mean_squared_error: 1.4586 - y2_output_root_mean_squared_error: 2.3358 - val_loss: 4.9509 - val_y1_output_loss: 1.3557 - val_y2_output_loss: 3.4215 - val_y1_output_root_mean_squared_error: 1.1855 - val_y2_output_root_mean_squared_error: 1.8830
# Epoch 59/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.4093 - y1_output_loss: 1.6093 - y2_output_loss: 4.7491 - y1_output_root_mean_squared_error: 1.2733 - y2_output_root_mean_squared_error: 2.1882 - val_loss: 4.2957 - val_y1_output_loss: 1.3667 - val_y2_output_loss: 2.7919 - val_y1_output_root_mean_squared_error: 1.1888 - val_y2_output_root_mean_squared_error: 1.6978
# Epoch 60/500
# 614/614 [==============================] - 0s 147us/sample - loss: 7.5752 - y1_output_loss: 1.9776 - y2_output_loss: 5.5267 - y1_output_root_mean_squared_error: 1.4127 - y2_output_root_mean_squared_error: 2.3621 - val_loss: 4.4438 - val_y1_output_loss: 1.3910 - val_y2_output_loss: 2.9158 - val_y1_output_root_mean_squared_error: 1.2002 - val_y2_output_root_mean_squared_error: 1.7330
# Epoch 61/500
# 614/614 [==============================] - 0s 149us/sample - loss: 5.8908 - y1_output_loss: 1.6400 - y2_output_loss: 4.2403 - y1_output_root_mean_squared_error: 1.2833 - y2_output_root_mean_squared_error: 2.0601 - val_loss: 4.4725 - val_y1_output_loss: 1.1931 - val_y2_output_loss: 3.1361 - val_y1_output_root_mean_squared_error: 1.1128 - val_y2_output_root_mean_squared_error: 1.7984
# Epoch 62/500
# 614/614 [==============================] - 0s 172us/sample - loss: 5.4327 - y1_output_loss: 1.5575 - y2_output_loss: 3.8657 - y1_output_root_mean_squared_error: 1.2399 - y2_output_root_mean_squared_error: 1.9737 - val_loss: 7.7806 - val_y1_output_loss: 2.1379 - val_y2_output_loss: 5.3662 - val_y1_output_root_mean_squared_error: 1.4872 - val_y2_output_root_mean_squared_error: 2.3598
# Epoch 63/500
# 614/614 [==============================] - 0s 161us/sample - loss: 4.8313 - y1_output_loss: 1.3311 - y2_output_loss: 3.5916 - y1_output_root_mean_squared_error: 1.1489 - y2_output_root_mean_squared_error: 1.8738 - val_loss: 9.5715 - val_y1_output_loss: 2.1552 - val_y2_output_loss: 7.0972 - val_y1_output_root_mean_squared_error: 1.4952 - val_y2_output_root_mean_squared_error: 2.7085
# Epoch 64/500
# 614/614 [==============================] - 0s 151us/sample - loss: 5.0802 - y1_output_loss: 1.2393 - y2_output_loss: 3.8675 - y1_output_root_mean_squared_error: 1.1118 - y2_output_root_mean_squared_error: 1.9606 - val_loss: 4.1986 - val_y1_output_loss: 1.0165 - val_y2_output_loss: 3.0466 - val_y1_output_root_mean_squared_error: 1.0251 - val_y2_output_root_mean_squared_error: 1.7742
# Epoch 65/500
# 614/614 [==============================] - 0s 175us/sample - loss: 4.3132 - y1_output_loss: 1.1896 - y2_output_loss: 3.1000 - y1_output_root_mean_squared_error: 1.0902 - y2_output_root_mean_squared_error: 1.7677 - val_loss: 5.0655 - val_y1_output_loss: 1.8766 - val_y2_output_loss: 3.0043 - val_y1_output_root_mean_squared_error: 1.3957 - val_y2_output_root_mean_squared_error: 1.7656
# Epoch 66/500
# 614/614 [==============================] - 0s 173us/sample - loss: 4.6846 - y1_output_loss: 1.2533 - y2_output_loss: 3.4198 - y1_output_root_mean_squared_error: 1.1245 - y2_output_root_mean_squared_error: 1.8494 - val_loss: 8.3947 - val_y1_output_loss: 1.9194 - val_y2_output_loss: 6.2042 - val_y1_output_root_mean_squared_error: 1.4116 - val_y2_output_root_mean_squared_error: 2.5303
# Epoch 67/500
# 614/614 [==============================] - 0s 196us/sample - loss: 5.6793 - y1_output_loss: 1.3596 - y2_output_loss: 4.4093 - y1_output_root_mean_squared_error: 1.1384 - y2_output_root_mean_squared_error: 2.0936 - val_loss: 13.6228 - val_y1_output_loss: 5.6081 - val_y2_output_loss: 7.7491 - val_y1_output_root_mean_squared_error: 2.3869 - val_y2_output_root_mean_squared_error: 2.8153
# Epoch 68/500
# 614/614 [==============================] - 0s 186us/sample - loss: 4.7695 - y1_output_loss: 1.4410 - y2_output_loss: 3.3212 - y1_output_root_mean_squared_error: 1.2042 - y2_output_root_mean_squared_error: 1.8219 - val_loss: 6.5974 - val_y1_output_loss: 0.9508 - val_y2_output_loss: 5.4404 - val_y1_output_root_mean_squared_error: 0.9917 - val_y2_output_root_mean_squared_error: 2.3694
# Epoch 69/500
# 614/614 [==============================] - 0s 174us/sample - loss: 7.2929 - y1_output_loss: 1.8257 - y2_output_loss: 5.4197 - y1_output_root_mean_squared_error: 1.3526 - y2_output_root_mean_squared_error: 2.3374 - val_loss: 3.5586 - val_y1_output_loss: 1.0329 - val_y2_output_loss: 2.4230 - val_y1_output_root_mean_squared_error: 1.0320 - val_y2_output_root_mean_squared_error: 1.5791
# Epoch 70/500
# 614/614 [==============================] - 0s 173us/sample - loss: 5.5027 - y1_output_loss: 1.3843 - y2_output_loss: 4.1164 - y1_output_root_mean_squared_error: 1.1756 - y2_output_root_mean_squared_error: 2.0299 - val_loss: 4.1832 - val_y1_output_loss: 1.6113 - val_y2_output_loss: 2.4255 - val_y1_output_root_mean_squared_error: 1.2924 - val_y2_output_root_mean_squared_error: 1.5852
# Epoch 71/500
# 614/614 [==============================] - 0s 161us/sample - loss: 3.6812 - y1_output_loss: 1.1108 - y2_output_loss: 2.5681 - y1_output_root_mean_squared_error: 1.0536 - y2_output_root_mean_squared_error: 1.6035 - val_loss: 3.4197 - val_y1_output_loss: 0.8789 - val_y2_output_loss: 2.4304 - val_y1_output_root_mean_squared_error: 0.9549 - val_y2_output_root_mean_squared_error: 1.5836
# Epoch 72/500
# 614/614 [==============================] - 0s 220us/sample - loss: 3.5539 - y1_output_loss: 0.8610 - y2_output_loss: 2.7006 - y1_output_root_mean_squared_error: 0.9322 - y2_output_root_mean_squared_error: 1.6385 - val_loss: 6.7208 - val_y1_output_loss: 1.6908 - val_y2_output_loss: 4.7965 - val_y1_output_root_mean_squared_error: 1.3238 - val_y2_output_root_mean_squared_error: 2.2290
# Epoch 73/500
# 614/614 [==============================] - 0s 184us/sample - loss: 5.2309 - y1_output_loss: 1.2161 - y2_output_loss: 4.1103 - y1_output_root_mean_squared_error: 1.0927 - y2_output_root_mean_squared_error: 2.0092 - val_loss: 45.8105 - val_y1_output_loss: 12.0437 - val_y2_output_loss: 32.1218 - val_y1_output_root_mean_squared_error: 3.5364 - val_y2_output_root_mean_squared_error: 5.7710
# Epoch 74/500
# 614/614 [==============================] - 0s 163us/sample - loss: 12.7697 - y1_output_loss: 4.2279 - y2_output_loss: 8.4400 - y1_output_root_mean_squared_error: 2.0636 - y2_output_root_mean_squared_error: 2.9174 - val_loss: 5.5233 - val_y1_output_loss: 1.6241 - val_y2_output_loss: 3.7099 - val_y1_output_root_mean_squared_error: 1.2955 - val_y2_output_root_mean_squared_error: 1.9609
# Epoch 75/500
# 614/614 [==============================] - 0s 164us/sample - loss: 3.2376 - y1_output_loss: 0.7590 - y2_output_loss: 2.4617 - y1_output_root_mean_squared_error: 0.8733 - y2_output_root_mean_squared_error: 1.5732 - val_loss: 3.7354 - val_y1_output_loss: 1.1056 - val_y2_output_loss: 2.5619 - val_y1_output_root_mean_squared_error: 1.0635 - val_y2_output_root_mean_squared_error: 1.6138
# Epoch 76/500
# 614/614 [==============================] - 0s 181us/sample - loss: 3.1937 - y1_output_loss: 0.7501 - y2_output_loss: 2.4176 - y1_output_root_mean_squared_error: 0.8688 - y2_output_root_mean_squared_error: 1.5617 - val_loss: 2.6316 - val_y1_output_loss: 0.6442 - val_y2_output_loss: 1.8949 - val_y1_output_root_mean_squared_error: 0.8178 - val_y2_output_root_mean_squared_error: 1.4010
# Epoch 77/500
# 614/614 [==============================] - 0s 167us/sample - loss: 4.8211 - y1_output_loss: 1.3044 - y2_output_loss: 3.4788 - y1_output_root_mean_squared_error: 1.1462 - y2_output_root_mean_squared_error: 1.8728 - val_loss: 3.6178 - val_y1_output_loss: 1.2180 - val_y2_output_loss: 2.2753 - val_y1_output_root_mean_squared_error: 1.1226 - val_y2_output_root_mean_squared_error: 1.5354
# Epoch 78/500
# 614/614 [==============================] - 0s 162us/sample - loss: 2.4989 - y1_output_loss: 0.6752 - y2_output_loss: 1.8063 - y1_output_root_mean_squared_error: 0.8247 - y2_output_root_mean_squared_error: 1.3486 - val_loss: 2.2615 - val_y1_output_loss: 0.5341 - val_y2_output_loss: 1.6477 - val_y1_output_root_mean_squared_error: 0.7445 - val_y2_output_root_mean_squared_error: 1.3066
# Epoch 79/500
# 614/614 [==============================] - 0s 178us/sample - loss: 2.6447 - y1_output_loss: 0.6871 - y2_output_loss: 1.9773 - y1_output_root_mean_squared_error: 0.8241 - y2_output_root_mean_squared_error: 1.4020 - val_loss: 2.2456 - val_y1_output_loss: 0.5082 - val_y2_output_loss: 1.6697 - val_y1_output_root_mean_squared_error: 0.7245 - val_y2_output_root_mean_squared_error: 1.3117
# Epoch 80/500
# 614/614 [==============================] - 0s 177us/sample - loss: 4.0492 - y1_output_loss: 0.9015 - y2_output_loss: 3.1182 - y1_output_root_mean_squared_error: 0.9516 - y2_output_root_mean_squared_error: 1.7730 - val_loss: 3.2384 - val_y1_output_loss: 0.8961 - val_y2_output_loss: 2.2281 - val_y1_output_root_mean_squared_error: 0.9642 - val_y2_output_root_mean_squared_error: 1.5195
# Epoch 81/500
# 614/614 [==============================] - 0s 160us/sample - loss: 3.4815 - y1_output_loss: 0.8621 - y2_output_loss: 2.5951 - y1_output_root_mean_squared_error: 0.9308 - y2_output_root_mean_squared_error: 1.6171 - val_loss: 2.4784 - val_y1_output_loss: 0.5410 - val_y2_output_loss: 1.8698 - val_y1_output_root_mean_squared_error: 0.7443 - val_y2_output_root_mean_squared_error: 1.3872
# Epoch 82/500
# 614/614 [==============================] - 0s 165us/sample - loss: 2.9994 - y1_output_loss: 0.6742 - y2_output_loss: 2.3000 - y1_output_root_mean_squared_error: 0.8249 - y2_output_root_mean_squared_error: 1.5228 - val_loss: 2.9672 - val_y1_output_loss: 0.6667 - val_y2_output_loss: 2.2089 - val_y1_output_root_mean_squared_error: 0.8241 - val_y2_output_root_mean_squared_error: 1.5126
# Epoch 83/500
# 614/614 [==============================] - 0s 179us/sample - loss: 3.3616 - y1_output_loss: 0.8178 - y2_output_loss: 2.5379 - y1_output_root_mean_squared_error: 0.9071 - y2_output_root_mean_squared_error: 1.5933 - val_loss: 3.6989 - val_y1_output_loss: 1.0553 - val_y2_output_loss: 2.5303 - val_y1_output_root_mean_squared_error: 1.0391 - val_y2_output_root_mean_squared_error: 1.6184
# Epoch 84/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.6171 - y1_output_loss: 0.6224 - y2_output_loss: 2.0051 - y1_output_root_mean_squared_error: 0.7889 - y2_output_root_mean_squared_error: 1.4123 - val_loss: 1.8825 - val_y1_output_loss: 0.4512 - val_y2_output_loss: 1.3731 - val_y1_output_root_mean_squared_error: 0.6799 - val_y2_output_root_mean_squared_error: 1.1917
# Epoch 85/500
# 614/614 [==============================] - 0s 152us/sample - loss: 3.0604 - y1_output_loss: 0.6796 - y2_output_loss: 2.3741 - y1_output_root_mean_squared_error: 0.8264 - y2_output_root_mean_squared_error: 1.5419 - val_loss: 2.1260 - val_y1_output_loss: 0.5105 - val_y2_output_loss: 1.5399 - val_y1_output_root_mean_squared_error: 0.7258 - val_y2_output_root_mean_squared_error: 1.2646
# Epoch 86/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.8482 - y1_output_loss: 0.6477 - y2_output_loss: 2.1772 - y1_output_root_mean_squared_error: 0.8073 - y2_output_root_mean_squared_error: 1.4820 - val_loss: 2.1366 - val_y1_output_loss: 0.4684 - val_y2_output_loss: 1.6056 - val_y1_output_root_mean_squared_error: 0.6913 - val_y2_output_root_mean_squared_error: 1.2879
# Epoch 87/500
# 614/614 [==============================] - 0s 160us/sample - loss: 3.0507 - y1_output_loss: 0.6991 - y2_output_loss: 2.3295 - y1_output_root_mean_squared_error: 0.8388 - y2_output_root_mean_squared_error: 1.5320 - val_loss: 3.4230 - val_y1_output_loss: 0.9969 - val_y2_output_loss: 2.3270 - val_y1_output_root_mean_squared_error: 1.0044 - val_y2_output_root_mean_squared_error: 1.5538
# Epoch 88/500
# 614/614 [==============================] - 0s 158us/sample - loss: 3.1719 - y1_output_loss: 0.7595 - y2_output_loss: 2.3958 - y1_output_root_mean_squared_error: 0.8749 - y2_output_root_mean_squared_error: 1.5513 - val_loss: 2.4910 - val_y1_output_loss: 0.6961 - val_y2_output_loss: 1.7201 - val_y1_output_root_mean_squared_error: 0.8461 - val_y2_output_root_mean_squared_error: 1.3323
# Epoch 89/500
# 614/614 [==============================] - 0s 154us/sample - loss: 2.9352 - y1_output_loss: 0.6617 - y2_output_loss: 2.2604 - y1_output_root_mean_squared_error: 0.8152 - y2_output_root_mean_squared_error: 1.5069 - val_loss: 2.0683 - val_y1_output_loss: 0.4746 - val_y2_output_loss: 1.5263 - val_y1_output_root_mean_squared_error: 0.7003 - val_y2_output_root_mean_squared_error: 1.2561
# Epoch 90/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.0090 - y1_output_loss: 0.7164 - y2_output_loss: 2.3417 - y1_output_root_mean_squared_error: 0.8459 - y2_output_root_mean_squared_error: 1.5144 - val_loss: 13.7418 - val_y1_output_loss: 3.0236 - val_y2_output_loss: 10.3020 - val_y1_output_root_mean_squared_error: 1.7633 - val_y2_output_root_mean_squared_error: 3.2607
# Epoch 91/500
# 614/614 [==============================] - 0s 159us/sample - loss: 5.2316 - y1_output_loss: 1.3422 - y2_output_loss: 3.8625 - y1_output_root_mean_squared_error: 1.1601 - y2_output_root_mean_squared_error: 1.9712 - val_loss: 2.5591 - val_y1_output_loss: 0.4801 - val_y2_output_loss: 1.9880 - val_y1_output_root_mean_squared_error: 0.7048 - val_y2_output_root_mean_squared_error: 1.4361
# Epoch 92/500
# 614/614 [==============================] - 0s 155us/sample - loss: 2.8392 - y1_output_loss: 0.7431 - y2_output_loss: 2.0810 - y1_output_root_mean_squared_error: 0.8625 - y2_output_root_mean_squared_error: 1.4475 - val_loss: 2.1909 - val_y1_output_loss: 0.5609 - val_y2_output_loss: 1.5667 - val_y1_output_root_mean_squared_error: 0.7573 - val_y2_output_root_mean_squared_error: 1.2718
# Epoch 93/500
# 614/614 [==============================] - 0s 161us/sample - loss: 3.0817 - y1_output_loss: 0.6943 - y2_output_loss: 2.3748 - y1_output_root_mean_squared_error: 0.8344 - y2_output_root_mean_squared_error: 1.5445 - val_loss: 2.0101 - val_y1_output_loss: 0.5238 - val_y2_output_loss: 1.4194 - val_y1_output_root_mean_squared_error: 0.7327 - val_y2_output_root_mean_squared_error: 1.2138
# Epoch 94/500
# 614/614 [==============================] - 0s 185us/sample - loss: 3.5090 - y1_output_loss: 0.8317 - y2_output_loss: 2.6492 - y1_output_root_mean_squared_error: 0.9155 - y2_output_root_mean_squared_error: 1.6343 - val_loss: 1.7416 - val_y1_output_loss: 0.3920 - val_y2_output_loss: 1.2886 - val_y1_output_root_mean_squared_error: 0.6364 - val_y2_output_root_mean_squared_error: 1.1561
# Epoch 95/500
# 614/614 [==============================] - 0s 170us/sample - loss: 2.2034 - y1_output_loss: 0.5528 - y2_output_loss: 1.6452 - y1_output_root_mean_squared_error: 0.7431 - y2_output_root_mean_squared_error: 1.2850 - val_loss: 2.1773 - val_y1_output_loss: 0.6909 - val_y2_output_loss: 1.4124 - val_y1_output_root_mean_squared_error: 0.8456 - val_y2_output_root_mean_squared_error: 1.2092
# Epoch 96/500
# 614/614 [==============================] - 0s 159us/sample - loss: 2.0721 - y1_output_loss: 0.5342 - y2_output_loss: 1.5413 - y1_output_root_mean_squared_error: 0.7233 - y2_output_root_mean_squared_error: 1.2446 - val_loss: 3.1568 - val_y1_output_loss: 0.8666 - val_y2_output_loss: 2.2013 - val_y1_output_root_mean_squared_error: 0.9366 - val_y2_output_root_mean_squared_error: 1.5098
# Epoch 97/500
# 614/614 [==============================] - 0s 162us/sample - loss: 2.4614 - y1_output_loss: 0.6153 - y2_output_loss: 1.8664 - y1_output_root_mean_squared_error: 0.7831 - y2_output_root_mean_squared_error: 1.3595 - val_loss: 6.7404 - val_y1_output_loss: 1.3794 - val_y2_output_loss: 5.1287 - val_y1_output_root_mean_squared_error: 1.1926 - val_y2_output_root_mean_squared_error: 2.3061
# Epoch 98/500
# 614/614 [==============================] - 0s 169us/sample - loss: 2.4077 - y1_output_loss: 0.5693 - y2_output_loss: 1.8173 - y1_output_root_mean_squared_error: 0.7568 - y2_output_root_mean_squared_error: 1.3546 - val_loss: 2.6711 - val_y1_output_loss: 0.5250 - val_y2_output_loss: 2.0532 - val_y1_output_root_mean_squared_error: 0.7366 - val_y2_output_root_mean_squared_error: 1.4590
# Epoch 99/500
# 614/614 [==============================] - 0s 197us/sample - loss: 2.3230 - y1_output_loss: 0.5366 - y2_output_loss: 1.7654 - y1_output_root_mean_squared_error: 0.7354 - y2_output_root_mean_squared_error: 1.3350 - val_loss: 1.6770 - val_y1_output_loss: 0.3621 - val_y2_output_loss: 1.2614 - val_y1_output_root_mean_squared_error: 0.6110 - val_y2_output_root_mean_squared_error: 1.1418
# Epoch 100/500
# 614/614 [==============================] - 0s 180us/sample - loss: 2.8343 - y1_output_loss: 0.5753 - y2_output_loss: 2.2630 - y1_output_root_mean_squared_error: 0.7543 - y2_output_root_mean_squared_error: 1.5051 - val_loss: 3.5060 - val_y1_output_loss: 1.0663 - val_y2_output_loss: 2.3844 - val_y1_output_root_mean_squared_error: 1.0437 - val_y2_output_root_mean_squared_error: 1.5546
# Epoch 101/500
# 614/614 [==============================] - 0s 193us/sample - loss: 2.1313 - y1_output_loss: 0.4842 - y2_output_loss: 1.6402 - y1_output_root_mean_squared_error: 0.6922 - y2_output_root_mean_squared_error: 1.2854 - val_loss: 3.1416 - val_y1_output_loss: 1.2221 - val_y2_output_loss: 1.8118 - val_y1_output_root_mean_squared_error: 1.1231 - val_y2_output_root_mean_squared_error: 1.3712
# Epoch 102/500
# 614/614 [==============================] - 0s 180us/sample - loss: 2.7622 - y1_output_loss: 0.5886 - y2_output_loss: 2.1513 - y1_output_root_mean_squared_error: 0.7695 - y2_output_root_mean_squared_error: 1.4731 - val_loss: 2.4028 - val_y1_output_loss: 0.6339 - val_y2_output_loss: 1.6910 - val_y1_output_root_mean_squared_error: 0.8085 - val_y2_output_root_mean_squared_error: 1.3226
# Epoch 103/500
# 614/614 [==============================] - 0s 180us/sample - loss: 2.5063 - y1_output_loss: 0.5729 - y2_output_loss: 1.9302 - y1_output_root_mean_squared_error: 0.7603 - y2_output_root_mean_squared_error: 1.3886 - val_loss: 2.8494 - val_y1_output_loss: 0.7712 - val_y2_output_loss: 1.9786 - val_y1_output_root_mean_squared_error: 0.8929 - val_y2_output_root_mean_squared_error: 1.4325
# Epoch 104/500
# 614/614 [==============================] - 0s 197us/sample - loss: 2.6424 - y1_output_loss: 0.6120 - y2_output_loss: 2.0227 - y1_output_root_mean_squared_error: 0.7838 - y2_output_root_mean_squared_error: 1.4241 - val_loss: 4.1719 - val_y1_output_loss: 1.1351 - val_y2_output_loss: 2.9260 - val_y1_output_root_mean_squared_error: 1.0686 - val_y2_output_root_mean_squared_error: 1.7407
# Epoch 105/500
# 614/614 [==============================] - 0s 179us/sample - loss: 2.5252 - y1_output_loss: 0.5336 - y2_output_loss: 1.9690 - y1_output_root_mean_squared_error: 0.7339 - y2_output_root_mean_squared_error: 1.4094 - val_loss: 2.1444 - val_y1_output_loss: 0.5062 - val_y2_output_loss: 1.5667 - val_y1_output_root_mean_squared_error: 0.7192 - val_y2_output_root_mean_squared_error: 1.2756
# Epoch 106/500
# 614/614 [==============================] - 0s 169us/sample - loss: 2.0825 - y1_output_loss: 0.4600 - y2_output_loss: 1.6374 - y1_output_root_mean_squared_error: 0.6758 - y2_output_root_mean_squared_error: 1.2751 - val_loss: 4.4170 - val_y1_output_loss: 0.7543 - val_y2_output_loss: 3.5186 - val_y1_output_root_mean_squared_error: 0.8816 - val_y2_output_root_mean_squared_error: 1.9078
# Epoch 107/500
# 614/614 [==============================] - 0s 160us/sample - loss: 2.1193 - y1_output_loss: 0.4442 - y2_output_loss: 1.6863 - y1_output_root_mean_squared_error: 0.6657 - y2_output_root_mean_squared_error: 1.2946 - val_loss: 2.4526 - val_y1_output_loss: 0.6414 - val_y2_output_loss: 1.7427 - val_y1_output_root_mean_squared_error: 0.8116 - val_y2_output_root_mean_squared_error: 1.3394
# Epoch 108/500
# 614/614 [==============================] - 0s 178us/sample - loss: 1.6602 - y1_output_loss: 0.4034 - y2_output_loss: 1.2582 - y1_output_root_mean_squared_error: 0.6364 - y2_output_root_mean_squared_error: 1.1204 - val_loss: 2.5155 - val_y1_output_loss: 0.5278 - val_y2_output_loss: 1.9096 - val_y1_output_root_mean_squared_error: 0.7382 - val_y2_output_root_mean_squared_error: 1.4038
# Epoch 109/500
# 614/614 [==============================] - 0s 176us/sample - loss: 2.1105 - y1_output_loss: 0.4813 - y2_output_loss: 1.6142 - y1_output_root_mean_squared_error: 0.6934 - y2_output_root_mean_squared_error: 1.2766 - val_loss: 1.4842 - val_y1_output_loss: 0.3060 - val_y2_output_loss: 1.1274 - val_y1_output_root_mean_squared_error: 0.5612 - val_y2_output_root_mean_squared_error: 1.0813
# Epoch 110/500
# 614/614 [==============================] - 0s 161us/sample - loss: 2.2299 - y1_output_loss: 0.4900 - y2_output_loss: 1.7247 - y1_output_root_mean_squared_error: 0.7020 - y2_output_root_mean_squared_error: 1.3180 - val_loss: 2.1761 - val_y1_output_loss: 0.4829 - val_y2_output_loss: 1.6160 - val_y1_output_root_mean_squared_error: 0.7070 - val_y2_output_root_mean_squared_error: 1.2947
# Epoch 111/500
# 614/614 [==============================] - 0s 150us/sample - loss: 2.6594 - y1_output_loss: 0.6340 - y2_output_loss: 2.0547 - y1_output_root_mean_squared_error: 0.7927 - y2_output_root_mean_squared_error: 1.4252 - val_loss: 3.0907 - val_y1_output_loss: 1.3122 - val_y2_output_loss: 1.6998 - val_y1_output_root_mean_squared_error: 1.1535 - val_y2_output_root_mean_squared_error: 1.3267
# Epoch 112/500
# 614/614 [==============================] - 0s 158us/sample - loss: 1.6954 - y1_output_loss: 0.3938 - y2_output_loss: 1.2982 - y1_output_root_mean_squared_error: 0.6295 - y2_output_root_mean_squared_error: 1.1398 - val_loss: 1.5369 - val_y1_output_loss: 0.3728 - val_y2_output_loss: 1.1123 - val_y1_output_root_mean_squared_error: 0.6210 - val_y2_output_root_mean_squared_error: 1.0730
# Epoch 113/500
# 614/614 [==============================] - 0s 147us/sample - loss: 1.6350 - y1_output_loss: 0.4362 - y2_output_loss: 1.1885 - y1_output_root_mean_squared_error: 0.6631 - y2_output_root_mean_squared_error: 1.0933 - val_loss: 1.7065 - val_y1_output_loss: 0.3878 - val_y2_output_loss: 1.2625 - val_y1_output_root_mean_squared_error: 0.6302 - val_y2_output_root_mean_squared_error: 1.1443
# Epoch 114/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.7185 - y1_output_loss: 0.9226 - y2_output_loss: 2.7684 - y1_output_root_mean_squared_error: 0.9629 - y2_output_root_mean_squared_error: 1.6707 - val_loss: 1.7234 - val_y1_output_loss: 0.4099 - val_y2_output_loss: 1.2585 - val_y1_output_root_mean_squared_error: 0.6498 - val_y2_output_root_mean_squared_error: 1.1407
# Epoch 115/500
# 614/614 [==============================] - 0s 171us/sample - loss: 1.6804 - y1_output_loss: 0.4038 - y2_output_loss: 1.3290 - y1_output_root_mean_squared_error: 0.6328 - y2_output_root_mean_squared_error: 1.1313 - val_loss: 12.2797 - val_y1_output_loss: 1.9609 - val_y2_output_loss: 9.8891 - val_y1_output_root_mean_squared_error: 1.4244 - val_y2_output_root_mean_squared_error: 3.2017
# Epoch 116/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.6640 - y1_output_loss: 0.6232 - y2_output_loss: 2.0204 - y1_output_root_mean_squared_error: 0.7917 - y2_output_root_mean_squared_error: 1.4273 - val_loss: 1.6216 - val_y1_output_loss: 0.3724 - val_y2_output_loss: 1.1995 - val_y1_output_root_mean_squared_error: 0.6175 - val_y2_output_root_mean_squared_error: 1.1137
# Epoch 117/500
# 614/614 [==============================] - 0s 160us/sample - loss: 2.1124 - y1_output_loss: 0.4230 - y2_output_loss: 1.6906 - y1_output_root_mean_squared_error: 0.6479 - y2_output_root_mean_squared_error: 1.3010 - val_loss: 3.0090 - val_y1_output_loss: 0.5621 - val_y2_output_loss: 2.3465 - val_y1_output_root_mean_squared_error: 0.7601 - val_y2_output_root_mean_squared_error: 1.5592
# Epoch 118/500
# 614/614 [==============================] - 0s 182us/sample - loss: 1.6792 - y1_output_loss: 0.3764 - y2_output_loss: 1.3013 - y1_output_root_mean_squared_error: 0.6129 - y2_output_root_mean_squared_error: 1.1418 - val_loss: 1.7638 - val_y1_output_loss: 0.4655 - val_y2_output_loss: 1.2409 - val_y1_output_root_mean_squared_error: 0.6910 - val_y2_output_root_mean_squared_error: 1.1342
# Epoch 119/500
# 614/614 [==============================] - 0s 189us/sample - loss: 1.5042 - y1_output_loss: 0.3329 - y2_output_loss: 1.1605 - y1_output_root_mean_squared_error: 0.5773 - y2_output_root_mean_squared_error: 1.0821 - val_loss: 1.5341 - val_y1_output_loss: 0.3383 - val_y2_output_loss: 1.1423 - val_y1_output_root_mean_squared_error: 0.5903 - val_y2_output_root_mean_squared_error: 1.0889
# Epoch 120/500
# 614/614 [==============================] - 0s 187us/sample - loss: 1.6491 - y1_output_loss: 0.3760 - y2_output_loss: 1.2585 - y1_output_root_mean_squared_error: 0.6158 - y2_output_root_mean_squared_error: 1.1269 - val_loss: 1.3947 - val_y1_output_loss: 0.3277 - val_y2_output_loss: 1.0167 - val_y1_output_root_mean_squared_error: 0.5820 - val_y2_output_root_mean_squared_error: 1.0276
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 199us/sample - loss: 0.5289 - y1_output_loss: 0.1336 - y2_output_loss: 0.3995 - y1_output_root_mean_squared_error: 0.3662 - y2_output_root_mean_squared_error: 0.6283 - val_loss: 0.9532 - val_y1_output_loss: 0.1904 - val_y2_output_loss: 0.7372 - val_y1_output_root_mean_squared_error: 0.4416 - val_y2_output_root_mean_squared_error: 0.8708
# Epoch 462/500
# 614/614 [==============================] - 0s 189us/sample - loss: 0.3863 - y1_output_loss: 0.1217 - y2_output_loss: 0.2701 - y1_output_root_mean_squared_error: 0.3448 - y2_output_root_mean_squared_error: 0.5171 - val_loss: 2.0452 - val_y1_output_loss: 0.6609 - val_y2_output_loss: 1.3161 - val_y1_output_root_mean_squared_error: 0.8274 - val_y2_output_root_mean_squared_error: 1.1665
# Epoch 463/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.6435 - y1_output_loss: 0.1974 - y2_output_loss: 0.4428 - y1_output_root_mean_squared_error: 0.4449 - y2_output_root_mean_squared_error: 0.6675 - val_loss: 0.8819 - val_y1_output_loss: 0.1555 - val_y2_output_loss: 0.6995 - val_y1_output_root_mean_squared_error: 0.3986 - val_y2_output_root_mean_squared_error: 0.8503
# Epoch 464/500
# 614/614 [==============================] - 0s 167us/sample - loss: 0.5151 - y1_output_loss: 0.1539 - y2_output_loss: 0.3588 - y1_output_root_mean_squared_error: 0.3938 - y2_output_root_mean_squared_error: 0.6000 - val_loss: 0.7058 - val_y1_output_loss: 0.1939 - val_y2_output_loss: 0.4950 - val_y1_output_root_mean_squared_error: 0.4450 - val_y2_output_root_mean_squared_error: 0.7126
# Epoch 465/500
# 614/614 [==============================] - 0s 191us/sample - loss: 0.3376 - y1_output_loss: 0.1107 - y2_output_loss: 0.2256 - y1_output_root_mean_squared_error: 0.3332 - y2_output_root_mean_squared_error: 0.4760 - val_loss: 0.8051 - val_y1_output_loss: 0.2482 - val_y2_output_loss: 0.5304 - val_y1_output_root_mean_squared_error: 0.5062 - val_y2_output_root_mean_squared_error: 0.7408
# Epoch 466/500
# 614/614 [==============================] - 0s 166us/sample - loss: 0.3769 - y1_output_loss: 0.1210 - y2_output_loss: 0.2550 - y1_output_root_mean_squared_error: 0.3476 - y2_output_root_mean_squared_error: 0.5060 - val_loss: 0.9639 - val_y1_output_loss: 0.1910 - val_y2_output_loss: 0.7436 - val_y1_output_root_mean_squared_error: 0.4408 - val_y2_output_root_mean_squared_error: 0.8773
# Epoch 467/500
# 614/614 [==============================] - 0s 179us/sample - loss: 0.3302 - y1_output_loss: 0.1058 - y2_output_loss: 0.2238 - y1_output_root_mean_squared_error: 0.3254 - y2_output_root_mean_squared_error: 0.4736 - val_loss: 0.5971 - val_y1_output_loss: 0.1845 - val_y2_output_loss: 0.3949 - val_y1_output_root_mean_squared_error: 0.4351 - val_y2_output_root_mean_squared_error: 0.6385
# Epoch 468/500
# 614/614 [==============================] - 0s 192us/sample - loss: 0.4188 - y1_output_loss: 0.1296 - y2_output_loss: 0.2869 - y1_output_root_mean_squared_error: 0.3598 - y2_output_root_mean_squared_error: 0.5379 - val_loss: 0.5810 - val_y1_output_loss: 0.1719 - val_y2_output_loss: 0.3939 - val_y1_output_root_mean_squared_error: 0.4193 - val_y2_output_root_mean_squared_error: 0.6366
# Epoch 469/500
# 614/614 [==============================] - 0s 179us/sample - loss: 0.3984 - y1_output_loss: 0.1410 - y2_output_loss: 0.2549 - y1_output_root_mean_squared_error: 0.3763 - y2_output_root_mean_squared_error: 0.5067 - val_loss: 0.5961 - val_y1_output_loss: 0.2085 - val_y2_output_loss: 0.3704 - val_y1_output_root_mean_squared_error: 0.4610 - val_y2_output_root_mean_squared_error: 0.6193
# Epoch 470/500
# 614/614 [==============================] - 0s 174us/sample - loss: 0.3679 - y1_output_loss: 0.1319 - y2_output_loss: 0.2340 - y1_output_root_mean_squared_error: 0.3635 - y2_output_root_mean_squared_error: 0.4856 - val_loss: 0.5960 - val_y1_output_loss: 0.1806 - val_y2_output_loss: 0.3968 - val_y1_output_root_mean_squared_error: 0.4309 - val_y2_output_root_mean_squared_error: 0.6406
# Epoch 471/500
# 614/614 [==============================] - 0s 172us/sample - loss: 0.2863 - y1_output_loss: 0.1007 - y2_output_loss: 0.1842 - y1_output_root_mean_squared_error: 0.3182 - y2_output_root_mean_squared_error: 0.4303 - val_loss: 0.5649 - val_y1_output_loss: 0.1567 - val_y2_output_loss: 0.3971 - val_y1_output_root_mean_squared_error: 0.3982 - val_y2_output_root_mean_squared_error: 0.6375
# Epoch 472/500
# 614/614 [==============================] - 0s 168us/sample - loss: 0.3398 - y1_output_loss: 0.1102 - y2_output_loss: 0.2276 - y1_output_root_mean_squared_error: 0.3319 - y2_output_root_mean_squared_error: 0.4792 - val_loss: 0.5665 - val_y1_output_loss: 0.1709 - val_y2_output_loss: 0.3801 - val_y1_output_root_mean_squared_error: 0.4168 - val_y2_output_root_mean_squared_error: 0.6267
# Epoch 473/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.3936 - y1_output_loss: 0.1233 - y2_output_loss: 0.2687 - y1_output_root_mean_squared_error: 0.3518 - y2_output_root_mean_squared_error: 0.5194 - val_loss: 0.6186 - val_y1_output_loss: 0.2082 - val_y2_output_loss: 0.3938 - val_y1_output_root_mean_squared_error: 0.4613 - val_y2_output_root_mean_squared_error: 0.6370
# Epoch 474/500
# 614/614 [==============================] - 0s 177us/sample - loss: 0.3340 - y1_output_loss: 0.1194 - y2_output_loss: 0.2149 - y1_output_root_mean_squared_error: 0.3463 - y2_output_root_mean_squared_error: 0.4627 - val_loss: 0.8170 - val_y1_output_loss: 0.2121 - val_y2_output_loss: 0.5801 - val_y1_output_root_mean_squared_error: 0.4656 - val_y2_output_root_mean_squared_error: 0.7747
# Epoch 475/500
# 614/614 [==============================] - 0s 187us/sample - loss: 0.4520 - y1_output_loss: 0.1387 - y2_output_loss: 0.3135 - y1_output_root_mean_squared_error: 0.3720 - y2_output_root_mean_squared_error: 0.5601 - val_loss: 0.6851 - val_y1_output_loss: 0.2182 - val_y2_output_loss: 0.4519 - val_y1_output_root_mean_squared_error: 0.4689 - val_y2_output_root_mean_squared_error: 0.6821
# Epoch 476/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.4244 - y1_output_loss: 0.1215 - y2_output_loss: 0.2995 - y1_output_root_mean_squared_error: 0.3497 - y2_output_root_mean_squared_error: 0.5496 - val_loss: 0.5927 - val_y1_output_loss: 0.1567 - val_y2_output_loss: 0.4185 - val_y1_output_root_mean_squared_error: 0.4001 - val_y2_output_root_mean_squared_error: 0.6577
# Epoch 477/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.3453 - y1_output_loss: 0.1128 - y2_output_loss: 0.2316 - y1_output_root_mean_squared_error: 0.3353 - y2_output_root_mean_squared_error: 0.4826 - val_loss: 0.6415 - val_y1_output_loss: 0.1678 - val_y2_output_loss: 0.4572 - val_y1_output_root_mean_squared_error: 0.4133 - val_y2_output_root_mean_squared_error: 0.6861
# Epoch 478/500
# 614/614 [==============================] - 0s 165us/sample - loss: 0.3405 - y1_output_loss: 0.1184 - y2_output_loss: 0.2237 - y1_output_root_mean_squared_error: 0.3457 - y2_output_root_mean_squared_error: 0.4701 - val_loss: 0.9548 - val_y1_output_loss: 0.2222 - val_y2_output_loss: 0.7104 - val_y1_output_root_mean_squared_error: 0.4771 - val_y2_output_root_mean_squared_error: 0.8527
# Epoch 479/500
# 614/614 [==============================] - 0s 163us/sample - loss: 0.3543 - y1_output_loss: 0.1185 - y2_output_loss: 0.2398 - y1_output_root_mean_squared_error: 0.3434 - y2_output_root_mean_squared_error: 0.4862 - val_loss: 1.1030 - val_y1_output_loss: 0.3060 - val_y2_output_loss: 0.7638 - val_y1_output_root_mean_squared_error: 0.5608 - val_y2_output_root_mean_squared_error: 0.8880
# Epoch 480/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.6344 - y1_output_loss: 0.1478 - y2_output_loss: 0.4861 - y1_output_root_mean_squared_error: 0.3860 - y2_output_root_mean_squared_error: 0.6967 - val_loss: 0.9782 - val_y1_output_loss: 0.2003 - val_y2_output_loss: 0.7496 - val_y1_output_root_mean_squared_error: 0.4539 - val_y2_output_root_mean_squared_error: 0.8787
# Epoch 481/500
# 614/614 [==============================] - 0s 166us/sample - loss: 0.5351 - y1_output_loss: 0.1434 - y2_output_loss: 0.3894 - y1_output_root_mean_squared_error: 0.3799 - y2_output_root_mean_squared_error: 0.6251 - val_loss: 0.5554 - val_y1_output_loss: 0.1397 - val_y2_output_loss: 0.4003 - val_y1_output_root_mean_squared_error: 0.3773 - val_y2_output_root_mean_squared_error: 0.6427
# Epoch 482/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3832 - y1_output_loss: 0.1263 - y2_output_loss: 0.2644 - y1_output_root_mean_squared_error: 0.3516 - y2_output_root_mean_squared_error: 0.5095 - val_loss: 1.6211 - val_y1_output_loss: 0.3358 - val_y2_output_loss: 1.2318 - val_y1_output_root_mean_squared_error: 0.5871 - val_y2_output_root_mean_squared_error: 1.1298
# Epoch 483/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.4005 - y1_output_loss: 0.1336 - y2_output_loss: 0.2650 - y1_output_root_mean_squared_error: 0.3663 - y2_output_root_mean_squared_error: 0.5160 - val_loss: 0.6140 - val_y1_output_loss: 0.1568 - val_y2_output_loss: 0.4403 - val_y1_output_root_mean_squared_error: 0.4004 - val_y2_output_root_mean_squared_error: 0.6735
# Epoch 484/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.3707 - y1_output_loss: 0.1274 - y2_output_loss: 0.2461 - y1_output_root_mean_squared_error: 0.3537 - y2_output_root_mean_squared_error: 0.4956 - val_loss: 1.0711 - val_y1_output_loss: 0.2837 - val_y2_output_loss: 0.7587 - val_y1_output_root_mean_squared_error: 0.5398 - val_y2_output_root_mean_squared_error: 0.8830
# Epoch 485/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3136 - y1_output_loss: 0.1087 - y2_output_loss: 0.2035 - y1_output_root_mean_squared_error: 0.3309 - y2_output_root_mean_squared_error: 0.4518 - val_loss: 0.6190 - val_y1_output_loss: 0.1686 - val_y2_output_loss: 0.4458 - val_y1_output_root_mean_squared_error: 0.4097 - val_y2_output_root_mean_squared_error: 0.6717
# Epoch 486/500
# 614/614 [==============================] - 0s 177us/sample - loss: 0.3553 - y1_output_loss: 0.1203 - y2_output_loss: 0.2328 - y1_output_root_mean_squared_error: 0.3468 - y2_output_root_mean_squared_error: 0.4848 - val_loss: 0.5715 - val_y1_output_loss: 0.1622 - val_y2_output_loss: 0.3930 - val_y1_output_root_mean_squared_error: 0.4057 - val_y2_output_root_mean_squared_error: 0.6379
# Epoch 487/500
# 614/614 [==============================] - 0s 179us/sample - loss: 0.3269 - y1_output_loss: 0.1145 - y2_output_loss: 0.2143 - y1_output_root_mean_squared_error: 0.3383 - y2_output_root_mean_squared_error: 0.4609 - val_loss: 1.1009 - val_y1_output_loss: 0.2003 - val_y2_output_loss: 0.8647 - val_y1_output_root_mean_squared_error: 0.4532 - val_y2_output_root_mean_squared_error: 0.9463
# Epoch 488/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.3468 - y1_output_loss: 0.1166 - y2_output_loss: 0.2280 - y1_output_root_mean_squared_error: 0.3419 - y2_output_root_mean_squared_error: 0.4795 - val_loss: 0.5423 - val_y1_output_loss: 0.1457 - val_y2_output_loss: 0.3835 - val_y1_output_root_mean_squared_error: 0.3838 - val_y2_output_root_mean_squared_error: 0.6285
# Epoch 489/500
# 614/614 [==============================] - 0s 165us/sample - loss: 0.3067 - y1_output_loss: 0.1077 - y2_output_loss: 0.1997 - y1_output_root_mean_squared_error: 0.3285 - y2_output_root_mean_squared_error: 0.4458 - val_loss: 0.8640 - val_y1_output_loss: 0.2589 - val_y2_output_loss: 0.5856 - val_y1_output_root_mean_squared_error: 0.5125 - val_y2_output_root_mean_squared_error: 0.7754
# Epoch 490/500
# 614/614 [==============================] - 0s 173us/sample - loss: 0.3898 - y1_output_loss: 0.1304 - y2_output_loss: 0.2565 - y1_output_root_mean_squared_error: 0.3627 - y2_output_root_mean_squared_error: 0.5083 - val_loss: 0.6953 - val_y1_output_loss: 0.2289 - val_y2_output_loss: 0.4495 - val_y1_output_root_mean_squared_error: 0.4828 - val_y2_output_root_mean_squared_error: 0.6798
# Epoch 491/500
# 614/614 [==============================] - 0s 166us/sample - loss: 0.4109 - y1_output_loss: 0.1224 - y2_output_loss: 0.2860 - y1_output_root_mean_squared_error: 0.3508 - y2_output_root_mean_squared_error: 0.5365 - val_loss: 0.5720 - val_y1_output_loss: 0.1431 - val_y2_output_loss: 0.4117 - val_y1_output_root_mean_squared_error: 0.3822 - val_y2_output_root_mean_squared_error: 0.6526
# Epoch 492/500
# 614/614 [==============================] - 0s 170us/sample - loss: 0.5671 - y1_output_loss: 0.1513 - y2_output_loss: 0.4128 - y1_output_root_mean_squared_error: 0.3902 - y2_output_root_mean_squared_error: 0.6441 - val_loss: 0.8258 - val_y1_output_loss: 0.1748 - val_y2_output_loss: 0.6258 - val_y1_output_root_mean_squared_error: 0.4231 - val_y2_output_root_mean_squared_error: 0.8042
# Epoch 493/500
# 614/614 [==============================] - 0s 175us/sample - loss: 0.4382 - y1_output_loss: 0.1454 - y2_output_loss: 0.2911 - y1_output_root_mean_squared_error: 0.3807 - y2_output_root_mean_squared_error: 0.5415 - val_loss: 0.8607 - val_y1_output_loss: 0.3535 - val_y2_output_loss: 0.4827 - val_y1_output_root_mean_squared_error: 0.6027 - val_y2_output_root_mean_squared_error: 0.7053
# Epoch 494/500
# 614/614 [==============================] - 0s 186us/sample - loss: 0.4730 - y1_output_loss: 0.1422 - y2_output_loss: 0.3274 - y1_output_root_mean_squared_error: 0.3782 - y2_output_root_mean_squared_error: 0.5744 - val_loss: 0.6571 - val_y1_output_loss: 0.2048 - val_y2_output_loss: 0.4348 - val_y1_output_root_mean_squared_error: 0.4577 - val_y2_output_root_mean_squared_error: 0.6691
# Epoch 495/500
# 614/614 [==============================] - 0s 169us/sample - loss: 0.4165 - y1_output_loss: 0.1294 - y2_output_loss: 0.2885 - y1_output_root_mean_squared_error: 0.3606 - y2_output_root_mean_squared_error: 0.5352 - val_loss: 0.6259 - val_y1_output_loss: 0.1471 - val_y2_output_loss: 0.4664 - val_y1_output_root_mean_squared_error: 0.3847 - val_y2_output_root_mean_squared_error: 0.6913
# Epoch 496/500
# 614/614 [==============================] - 0s 178us/sample - loss: 0.3514 - y1_output_loss: 0.1303 - y2_output_loss: 0.2274 - y1_output_root_mean_squared_error: 0.3592 - y2_output_root_mean_squared_error: 0.4716 - val_loss: 1.1735 - val_y1_output_loss: 0.3077 - val_y2_output_loss: 0.8283 - val_y1_output_root_mean_squared_error: 0.5622 - val_y2_output_root_mean_squared_error: 0.9260
# Epoch 497/500
# 614/614 [==============================] - 0s 190us/sample - loss: 0.3957 - y1_output_loss: 0.1187 - y2_output_loss: 0.2750 - y1_output_root_mean_squared_error: 0.3456 - y2_output_root_mean_squared_error: 0.5256 - val_loss: 0.5800 - val_y1_output_loss: 0.1521 - val_y2_output_loss: 0.4121 - val_y1_output_root_mean_squared_error: 0.3939 - val_y2_output_root_mean_squared_error: 0.6518
# Epoch 498/500
# 614/614 [==============================] - 0s 172us/sample - loss: 0.4078 - y1_output_loss: 0.1486 - y2_output_loss: 0.2675 - y1_output_root_mean_squared_error: 0.3840 - y2_output_root_mean_squared_error: 0.5102 - val_loss: 2.7448 - val_y1_output_loss: 0.4295 - val_y2_output_loss: 2.2272 - val_y1_output_root_mean_squared_error: 0.6653 - val_y2_output_root_mean_squared_error: 1.5173
# Epoch 499/500
# 614/614 [==============================] - 0s 177us/sample - loss: 0.3789 - y1_output_loss: 0.1264 - y2_output_loss: 0.2524 - y1_output_root_mean_squared_error: 0.3547 - y2_output_root_mean_squared_error: 0.5031 - val_loss: 0.7078 - val_y1_output_loss: 0.1978 - val_y2_output_loss: 0.4909 - val_y1_output_root_mean_squared_error: 0.4487 - val_y2_output_root_mean_squared_error: 0.7116
# Epoch 500/500
# 614/614 [==============================] - 0s 181us/sample - loss: 0.3445 - y1_output_loss: 0.1258 - y2_output_loss: 0.2245 - y1_output_root_mean_squared_error: 0.3505 - y2_output_root_mean_squared_error: 0.4708 - val_loss: 0.7927 - val_y1_output_loss: 0.2762 - val_y2_output_loss: 0.4958 - val_y1_output_root_mean_squared_error: 0.5306 - val_y2_output_root_mean_squared_error: 0.7150

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 45us/sample - loss: 0.7927 - y1_output_loss: 0.2784 - y2_output_loss: 0.5022 - y1_output_root_mean_squared_error: 0.5306 - y2_output_root_mean_squared_error: 0.7150
# Loss = 0.79273190049382, Y1_loss = 0.2784043252468109, Y1_mse = 0.5305501818656921, Y2_loss = 0.5022257566452026, Y2_mse = 0.7150163650512695

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
