# %% [markdown]
# # Autocorrect

# %% [markdown]
# `Autocorrect` changes misspelled words into correct ones.
#
# Autocorrect model steps:
# - Identify a misspelled word
# ```python
# for word in phrase:
#     if word not in vocabulary:
#         misspelled=True
# ```
# - Find strings n edit distance away, `by inserting, deleting, replacing  or switching (2 neighbour)letters`
# ```python
# words=[]
# for i in range(len(word)):
#     words.append(word[:i]+word[i+1:])
# ```
# - Filter candidates `(leave only words present in the vocabulary)`
# ```python
# vocab = ['dean','deer','dear','fries','and','coke']
# edits = list(deletes)
# candidates = [word for word in edits if word in vocab]
# ```
#
# - Calculate word probabilities

# %% [markdown]
# ### Minimum edit distance
# Mnimum `number of edits` needed to transform one string into another. play -> stay needs 2 edits (2 replaces or 2 deletes followed by 2 inserts making it up for a cost of 4)
# - inserting (cost 1)
# - deleting (cost 1)
# - replacing (cost 2)
#
# ![image.png](attachment:image.png)
